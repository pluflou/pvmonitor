# %%
# %matplotlib widget

# %%
from new_monitor import PvMonitor
import warnings
warnings.filterwarnings("ignore")

# %%
mon = PvMonitor(
pv_list = ["OTRS:IN20:571:XRMS_CU_HXR_LUME", "OTRS:IN20:571:YRMS_CU_HXR_LUME", "OTRS:IN20:571:ZRMS_CU_HXR_LUME",
       "OTRS:IN20:571:EMITN_X_CU_HXR_LUME", "OTRS:IN20:571:EMITN_Y_CU_HXR_LUME"],
    pv_groups= [[0,1], [2], [3,4]],
    group_titles= ["Transverse Beam Sizes", "Longitudinal Beam Size", "Normalized Emittances"],
    time_window=300,
    n_cols=3
)

# %%
mon.run()
# Out:
# Monitor started. Call monitor.stop() to stop.
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
import epics

# %%
epics.caget_many(pvs)
# Out:
# [657.4192919419448, 680.6065887364708, 0.004998886885984677]
